# %%
import pandas as pd

# Read the CSV file
airbnb_data = pd.read_csv("UserData.csv")

# View the first 5 rows
airbnb_data.head()
# Out:
#       Monthly_Income Investment_Percentage         Emergency_Fund  \
# 0  ₹50,000–₹1,00,000               10%–20%  No, but working on it
# 1    Above ₹1,00,000         Less than 10%                    Yes
# 2    Above ₹1,00,000               10%–20%                    Yes
# 3  ₹50,000–₹1,00,000         More than 20%                     No
# 4        Be1 ₹50,000         Less than 10%  No, but working on it
#
#             "Debt_Level"         "Investment_Goals"  "Expected_Returns"  \
# 0  None or less than 10%  Long-term wealth creation             10%–15%
# 1                10%–30%           Short-term gains             10%–15%
# 2                10%–30%             Steady returns           Above 15%
# 3                10%–30%           Short-term gains             Be1 10%
# 4                10%–30%  Long-term wealth creation             10%–15%
#
#     "Volatility_Reaction"  "Loss_Reaction"  "Risk_Allocation"  "Company_type"  \
# ...
