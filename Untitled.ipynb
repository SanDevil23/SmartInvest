# %%
import pandas as pd

# Read the CSV file
user_data = pd.read_csv("Sample_Risk_Appetite_Data.csv")

for i in user_data:
# Out:
#       Monthly_Income Investment_Percentage         Emergency_Fund  \
# 0  ₹50,000–₹1,00,000         Less than 10%  No, but working on it
# 1    Above ₹1,00,000               10%–20%                    Yes
# 2    Above ₹1,00,000         Less than 10%                    Yes
# 3  ₹50,000–₹1,00,000               10%–20%                     No
# 4      Below ₹50,000         More than 20%  No, but working on it
#
#               Debt_Level            Investment_Goal Expected_Return  \
# 0  None or less than 10%  Long-term wealth creation         10%–15%
# 1                10%–30%           Short-term gains         10%–15%
# 2                10%–30%             Steady returns       Above 15%
# 3                10%–30%           Short-term gains       Below 10%
# 4                10%–30%  Long-term wealth creation         10%–15%
#
#       Volatility_Reaction        Loss_Reaction High_Risk_Allocation  \
# 0  Stay calm and buy more       Hold the stock        Less than 25%
# ...
